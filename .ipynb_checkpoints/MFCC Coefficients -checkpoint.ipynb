# %%
# !pip install numpy
# !pip install scipy
# !pip install matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (1.19.5)
# Requirement already satisfied: scipy in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (from scipy) (1.19.5)
# Requirement already satisfied: matplotlib in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (3.4.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (from matplotlib) (1.19.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (from matplotlib) (8.3.2)
# Requirement already satisfied: six in c:\users\yashm\anaconda3\envs\tfod\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)

# %% [markdown]
# # 1. Setup of the Analog Speech Signal

# %%
import numpy
import scipy.io.wavfile
from scipy.fftpack import dct
import matplotlib.pyplot as plt
import librosa.display

audio_path = './OSR_us_000_0010_8k.wav'
sr = 8000
signal , sample_rate = librosa.load(audio_path,sr=sr)  # File assumed to be in the same directory
signal = signal[0:int(3.5 * sample_rate)]  # Keep the first 3.5 seconds
time = numpy.linspace(0,3.5,signal.size)
signal.size,sample_rate
# Out:
# (28000, 8000)

# %%
plt.plot(time,signal)
plt.xlabel("Time")
plt.ylabel("Amplitude")
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
import IPython.display as ipd

# Only take for first 3.5 seconds for analysis
ipd.Audio(audio_path,)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 2. Pre-Emphasis

# %%
# pre-emphasis filter on the signal to amplify the high frequencies
# Using first ordrer filter


pre_emphasis = 0.97
emphasized_signal = numpy.append(signal[0], signal[1:] - pre_emphasis * signal[:-1])
emphasized_signal.size
# Out:
# 28000

# %%
plt.plot(time,emphasized_signal)
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.title("Emphasised signal")
# Out:
# Text(0.5, 1.0, 'Emphasised signal')

# %% [markdown]
# # 3. Framing

# %%
# split the signal into short-time frames 
#  25 milli-seconds

frame_size = 0.025
frame_stride = 0.01

frame_length, frame_step = frame_size * sample_rate, frame_stride * sample_rate  # Convert from seconds to samples
signal_length = len(emphasized_signal)
frame_length = int(round(frame_length))
frame_step = int(round(frame_step))
num_frames = int(numpy.ceil(float(numpy.abs(signal_length - frame_length)) / frame_step))  # Make sure that we have at least 1 frame

pad_signal_length = num_frames * frame_step + frame_length
z = numpy.zeros((pad_signal_length - signal_length))
pad_signal = numpy.append(emphasized_signal, z) # Pad Signal to make sure that all frames have equal number of samples without truncating any samples from the original signal

indices = numpy.tile(numpy.arange(0, frame_length), (num_frames, 1)) + numpy.tile(numpy.arange(0, num_frames * frame_step, frame_step), (frame_length, 1)).T
frames = pad_signal[indices.astype(numpy.int32, copy=False)]

# each frame is of 1102 length, and the entire signal length is 154350 so there will be nearly 140 frames to be calculated 
fig , ((ax0,ax1) , (ax2,ax3)) = plt.subplots(nrows = 2, ncols=2, figsize=(15,10))

# Plot
ax0.plot(frames[0])
ax1.plot(frames[1])
ax2.plot(frames[2])
ax3.plot(frames[200])

frames_temp = frames 
len(frames)
# Out:
# 348

# %% [markdown]
# # 4. Hamming Window

# %%
frames *= numpy.hamming(frame_length)
print(f"Frame Length : {frame_length} ")
# frames *= 0.54 - 0.46 * numpy.cos((2 * numpy.pi * n) / (frame_length - 1))  # Explicit Implementation **

plt.plot(numpy.hamming(frame_length))
plt.xlabel("Samples")
plt.ylabel("Amplitude")
plt.title("Hamming window")


# different frames after hammimg window
fig , ((ax0,ax1) , (ax2,ax3)) = plt.subplots(nrows = 2, ncols=2, figsize=(15,10))

# Plot
ax0.plot(frames[0])
ax1.plot(frames[1])
ax2.plot(frames[2])
ax3.plot(frames[200])
# ax3.plot(without_window[347])

# plt.figure()
# plt.plot(without_window[0])
# Out:
# Frame Length : 200

# %% [markdown]
# # 5. Fourier-Transform and Power Spectrum

# %%
# N -point FFT on each frame to calculate the frequency spectrum

NFFT = 512

mag_frames = numpy.absolute(numpy.fft.rfft(frames, NFFT))  # Magnitude of the FFT
pow_frames = ((1.0 / NFFT) * ((mag_frames) ** 2))  # Power Spectrum

# %%
fig , ((ax0,ax1)) = plt.subplots(nrows = 1, ncols=2, figsize=(20,8))

# Plot
ax0.plot(mag_frames[200])
ax1.plot(pow_frames[200])

# plt.plot(mag_frames[200])
# plt.title("Magnitude")

# %% [markdown]
# # 6. Filter Banks

# %%
nfilt = 26  # or 40
low_freq_mel = 0
high_freq_mel = (2595 * numpy.log10(1 + (sample_rate / 2) / 700))  # Convert Hz to Mel
mel_points = numpy.linspace(low_freq_mel, high_freq_mel, nfilt + 2)  # Equally spaced in Mel scale
hz_points = (700 * (10**(mel_points / 2595) - 1))  # Convert Mel to Hz
bin = numpy.floor((NFFT + 1) * hz_points / sample_rate)

fbank = numpy.zeros((nfilt, int(numpy.floor(NFFT / 2 + 1))))
for m in range(1, nfilt + 1):
    f_m_minus = int(bin[m - 1])   # left
    f_m = int(bin[m])             # center
    f_m_plus = int(bin[m + 1])    # right

    for k in range(f_m_minus, f_m):
        fbank[m - 1, k] = (k - bin[m - 1]) / (bin[m] - bin[m - 1])
    for k in range(f_m, f_m_plus):
        fbank[m - 1, k] = (bin[m + 1] - k) / (bin[m + 1] - bin[m])
filter_banks = numpy.dot(pow_frames, fbank.T)
filter_banks = numpy.where(filter_banks == 0, numpy.finfo(float).eps, filter_banks)  # Numerical Stability
filter_banks = 20 * numpy.log10(filter_banks)  # dB

# %% [markdown]
# # 7. Mel-frequency Cepstral Coefficients (MFCCs)

# %%
# Discrete Cosine Transform (DCT)

num_ceps = 12
mfcc = dct(filter_banks, type=2, axis=1, norm='ortho')[:, 1 : (num_ceps + 1)] # Keep 2-13

# Plot
print(f"No of frames : {len(mfcc)}")


fig , ((ax0,ax1) , (ax2,ax3)) = plt.subplots(nrows = 2, ncols=2, figsize=(15,10))

# Plot
ax0.plot(mfcc[0])
ax1.plot(mfcc[1])
ax2.plot(mfcc[2])
ax3.plot(mfcc[200])
# Out:
# No of frames : 348
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8924/244311560.py in <module>
#      12 # Plot
#      13 ax0.plot(mfcc[0])
# ---> 14 ax0.xlabel("First")
#      15 ax1.plot(mfcc[1])
#      16 ax2.plot(mfcc[2])
#
# AttributeError: 'AxesSubplot' object has no attribute 'xlabel'

# %%
# mfccs = librosa.feature.mfcc(signal, sr=sr)
# librosa.display.specshow(mfccs, sr=sr, x_axis='time')
# len(mfccs) , mfccs.size , mfccs
